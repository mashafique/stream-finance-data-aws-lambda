# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('results.csv')

# %%
data
# Out:
#    Company  Hourly_High  Hour
# 0     BYND        36.57    13
# 1     BYND        37.33    12
# 2     BYND        36.95    14
# 3     BYND        37.99    10
# 4     BYND        24.67    16
# ..     ...          ...   ...
# 75     TTD        62.12    15
# 76     TTD        52.50    16
# 77     TTD        61.22     9
# 78     TTD        60.28    14
# 79     TTD        60.64    11
#
# [80 rows x 3 columns]

# %% [markdown]
# # Highest Stock Price at the First Trading Hour

# %%
data_at_9 = data[data['Hour'] == 9]
data_at_9
# Out:
#    Company  Hourly_High  Hour
# 7     BYND        37.80     9
# 13    DDOG       123.34     9
# 21      FB       210.73     9
# 27    NFLX       198.60     9
# 34    OKTA       123.35     9
# 42    PINS        21.24     9
# 50    SHOP       451.00     9
# 59    SNAP        29.54     9
# 68      SQ       103.07     9
# 77     TTD        61.22     9

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Company', y='Hourly_High', data=data_at_9)
plt.xlabel("Company", fontsize=20)
plt.ylabel("Stock Price", fontsize=20)
plt.title("Highest Stock Price at the First Trading Hour", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Highest Stock Price at the First Trading Hour')

# %% [markdown]
# # Highest Hourly Stock Price Trend

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Hour', y='Hourly_High', data=data, hue='Company')
plt.xlabel("Company", fontsize=20)
plt.ylabel("Stock Price", fontsize=20)
plt.title("Highest Stock Price Trend", fontsize=20)
plt.legend(loc='upper right')
